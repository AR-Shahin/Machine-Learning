# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
import os
import random
# Out:
# 2022-07-04 21:27:04.606456: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-04 21:27:04.606474: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
DIRECTORY = r"/home/user/ML/Deep Learning/CNN/Potato/PlantVillage"

CATEGORIES = ["Potato___Early_blight","Potato___healthy","Potato___Late_blight"]

IMAGE_SIZE = 100
BATCH_SIZE = 32

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.1
    )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
     rescale=1./255,
     validation_split=0.1
)

train_datagen = train_datagen.flow_from_directory(
    DIRECTORY,
    target_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE,
    subset = 'training'
)

test_datagen = test_datagen.flow_from_directory(
    DIRECTORY,
    target_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE,
    subset = 'validation'
)
# Out:
# Found 1937 images belonging to 3 classes.
# Found 215 images belonging to 3 classes.

# %%
train_datagen.class_indices
# Out:
# {'Potato___Early_blight': 0, 'Potato___Late_blight': 1, 'Potato___healthy': 2}

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense

model = Sequential()

# Layer One 
model.add(Conv2D(filters = 64, kernel_size = (3,3),activation = 'relu', input_shape = (IMAGE_SIZE,IMAGE_SIZE,3)))
model.add(MaxPooling2D(pool_size=2,strides=2))

model.add(Flatten())
model.add(Dense(3,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model.fit(train_datagen,epochs=20,validation_data=test_datagen)

model.summary()
# Out:
# Epoch 1/20
# 61/61 [==============================] - 9s 143ms/step - loss: 0.2815 - accuracy: 0.8864 - val_loss: 0.2906 - val_accuracy: 0.8698
# Epoch 2/20
# 61/61 [==============================] - 9s 143ms/step - loss: 0.1812 - accuracy: 0.9365 - val_loss: 0.3028 - val_accuracy: 0.8884
# Epoch 3/20
# 61/61 [==============================] - 9s 145ms/step - loss: 0.1726 - accuracy: 0.9391 - val_loss: 0.3740 - val_accuracy: 0.8419
# Epoch 4/20
# 61/61 [==============================] - 9s 154ms/step - loss: 0.1669 - accuracy: 0.9360 - val_loss: 0.2876 - val_accuracy: 0.8837
# Epoch 5/20
# 61/61 [==============================] - 9s 154ms/step - loss: 0.1170 - accuracy: 0.9582 - val_loss: 0.5207 - val_accuracy: 0.8093
# Epoch 6/20
# 61/61 [==============================] - 10s 161ms/step - loss: 0.1402 - accuracy: 0.9468 - val_loss: 0.4401 - val_accuracy: 0.8372
# Epoch 7/20
# 61/61 [==============================] - 15s 248ms/step - loss: 0.0969 - accuracy: 0.9659 - val_loss: 0.4043 - val_accuracy: 0.8419
# Epoch 8/20
# 61/61 [==============================] - 11s 181ms/step - loss: 0.1128 - accuracy: 0.9561 - val_loss: 0.1390 - val_accuracy: 0.9442
# Epoch 9/20
# 61/61 [==============================] - 10s 160ms/step - loss: 0.1170 - accuracy: 0.9592 - val_loss: 1.2781 - val_accuracy: 0.6884
# Epoch 10/20
# 61/61 [==============================] - 10s 164ms/step - loss: 0.1364 - accuracy: 0.9484 - val_loss: 0.2625 - val_accuracy: 0.8930
# Epoch 11/20
# 61/61 [==============================] - 10s 155ms/step - loss: 0.0779 - accuracy: 0.9721 - val_loss: 0.4388 - val_accuracy: 0.8512
# Epoch 12/20
# 61/61 [==============================] - 9s 146ms/step - loss: 0.0829 - accuracy: 0.9695 - val_loss: 0.2111 - val_accuracy: 0.9209
# Epoch 13/20
# 61/61 [==============================] - 9s 146ms/step - loss: 0.0903 - accuracy: 0.9623 - val_loss: 0.2903 - val_accuracy: 0.8977
# Epoch 14/20
# 61/61 [==============================] - 9s 147ms/step - loss: 0.0789 - accuracy: 0.9726 - val_loss: 0.0922 - val_accuracy: 0.9581
# Epoch 15/20
# 61/61 [==============================] - 10s 167ms/step - loss: 0.0863 - accuracy: 0.9675 - val_loss: 0.5242 - val_accuracy: 0.8279
# Epoch 16/20
# 61/61 [==============================] - 11s 171ms/step - loss: 0.0533 - accuracy: 0.9840 - val_loss: 0.8949 - val_accuracy: 0.7721
# Epoch 17/20
# 61/61 [==============================] - 12s 192ms/step - loss: 0.0634 - accuracy: 0.9716 - val_loss: 0.4585 - val_accuracy: 0.8512
# Epoch 18/20
# 61/61 [==============================] - 10s 160ms/step - loss: 0.0793 - accuracy: 0.9716 - val_loss: 0.1991 - val_accuracy: 0.9163
# Epoch 19/20
# 61/61 [==============================] - 11s 184ms/step - loss: 0.0764 - accuracy: 0.9695 - val_loss: 0.2185 - val_accuracy: 0.9163
# Epoch 20/20
# 61/61 [==============================] - 9s 150ms/step - loss: 0.0682 - accuracy: 0.9747 - val_loss: 0.2552 - val_accuracy: 0.8884
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 64)       0
#  )
#
#  flatten (Flatten)           (None, 153664)            0
#
#  dense (Dense)               (None, 3)                 460995
#
# =================================================================
# Total params: 462,787
# Trainable params: 462,787
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_result(index):
    for val in train_datagen.class_indices:
        if train_datagen.class_indices[val] == index:
            val = val.split("___")
            return val[1]
        


from keras.preprocessing import image
# path = "/home/user/ML/Deep Learning/CNN/Covid/test/net"
path = r"/home/user/ML/Deep Learning/CNN/Potato/Test"
img = path + "/healthy.JPG"
try:
    
    img_pred = tf.keras.utils.load_img(img,target_size=(IMAGE_SIZE,IMAGE_SIZE))
    img_pred = tf.keras.utils.img_to_array(img_pred)
    img_pred = img_pred / 255
    plt.imshow(img_pred)
    img_pred = np.expand_dims(img_pred, axis=0)
except:
    print("file not found!")

# %%
result = model.predict(img_pred)
index = np.argmax(result)
print("Index -> " , index)
print("Result -> " ,get_result(index))
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Index ->  2
# Result ->  healthy
